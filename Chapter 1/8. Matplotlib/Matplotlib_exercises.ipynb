# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv("C:/Users/User/Downloads/company_sales_data.csv")
print(data.to_string())
plt.plot(data["month_number"],data["total_profit"],label = "total profit")
plt.xlabel("Months")
plt.ylabel("Total profits")
plt.title("Companie's total profits over months")
plt.grid(True)
plt.legend()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  total_units  total_profit
# 0              1       2500      1500        5200         9200     1200         1500        21100        211000
# 1              2       2630      1200        5100         6100     2100         1200        18330        183300
# 2              3       2140      1340        4550         9550     3550         1340        22470        224700
# 3              4       3400      1130        5870         8870     1870         1130        22270        222700
# 4              5       3600      1740        4560         7760     1560         1740        20960        209600
# 5              6       2760      1555        4890         7490     1890         1555        20140        201400
# 6              7       2980      1120        4780         8980     1780         1120        29550        295500
# ...

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.plot(data["month_number"],data["total_profit"],label = "total profit",linestyle = "dotted",color = "r", marker = "o", mec="r",mfc = "k")
plt.xlabel("Months")
plt.ylabel("Total profits")
plt.title("Company sales data for last year")
plt.grid(True)
plt.legend(loc=4)

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))

plt.plot(data["month_number"],data["facecream"],label = "facecream", marker = "o")
plt.plot(data["month_number"],data["facewash"],label = "facewash",marker = "o")
plt.plot(data["month_number"],data["toothpaste"],label = "toothpaste",marker = "o")
plt.plot(data["month_number"],data["bathingsoap"],label = "bathingsoap",marker = "o")
plt.plot(data["month_number"],data["shampoo"],label = "shampoo",marker = "o")
plt.plot(data["month_number"],data["moisturizer"],label = "moisturizer",marker = "o")


plt.xlabel("Months")
plt.ylabel("Total units sold per month")
plt.title("Company sales data for last year")
plt.grid(True)
plt.legend()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.scatter(data["month_number"],data["toothpaste"],label = "toothpaste",marker = "o")

plt.xlabel("Months")
plt.ylabel("Total units sold per month")
plt.title("Company toothpaste sales data for last year")
plt.grid(True, ls = "--")
plt.legend()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

#plt.bar(data["month_number"],data["facecream"],label = "facecream")
#plt.bar(data["month_number"],data["facewash"],label = "facewash")

width = 0.4
fig, ax = plt.subplots(figsize = (8,6))
rects1 = ax.bar(data["month_number"] - width/2,data["facecream"] , width, label='Face cream sales')
rects2 = ax.bar(data["month_number"] + width/2,data["facewash"], width, label='Face wash sales')

plt.xlabel("Months")
plt.ylabel("Total units sold per month")
plt.title("Company toothpaste sales data for last year")
plt.grid(True, ls = "--")
plt.legend(loc=2)
fig.tight_layout()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.bar(data["month_number"],data["bathingsoap"],label = "bathing soap")
plt.xlabel("Months")
plt.ylabel("Total units sold per month")
plt.title("Company bathing soap sales data for last year")
plt.grid(True, ls = "--")
plt.legend(loc=2)

plt.savefig("output.jpg")

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.hist(data["total_profit"],label = "total profit")
plt.xlabel("Profit range in dollors")
plt.ylabel("Actual profit in dollors")
plt.title("Company profit range for last year")
plt.grid(True, ls = "--")
plt.legend(loc=1)
fig.tight_layout()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

fig, ax = plt.subplots(figsize=(8, 10), subplot_kw=dict(aspect="equal"))
Total_facecreams = data["facecream"].sum()
Total_facewash = data["facewash"].sum()
Total_toothpaste = data["toothpaste"].sum()
Total_bathingsoaps = data["bathingsoap"].sum()
Total_shampoo  = data["shampoo"].sum()
Total_moisturizer = data["moisturizer"].sum()
Total_units = data["total_units"].sum()
my_labels = data.columns[1:-2].values.tolist()

Total_units_sold = [Total_facecreams,Total_facewash,Total_toothpaste,Total_bathingsoaps,Total_shampoo,Total_moisturizer]

def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} units )".format(pct, absolute)


wedges, texts, autotexts = ax.pie(Total_units_sold, autopct=lambda pct: func(pct, Total_units_sold),textprops=dict(color="w"))

ax.legend(wedges, my_labels,
          title="Products list",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig, ax = plt.subplots(2)
fig.suptitle("face wash and bathingsoap sub plots")
#figsize=(10,8)
ax[1].plot(data["month_number"],data["facewash"],label = "facewash",color="r", marker = "o")
ax[1].set_title("sales of face wash")
ax[1].set_xlabel("months")
ax[1].set_ylabel("face wash units sold")

ax[0].plot(data["month_number"],data["bathingsoap"],label = "bathingsoap",color="k",marker = "o")
ax[0].set_title("sales of bath soap")
ax[0].set_xlabel("months")
ax[0].set_ylabel("bath soap units sold")
fig.tight_layout()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
new_data = data.drop(["total_units","total_profit"],axis=1)

ax =new_data.plot.area(x="month_number")

# plt.xlabel("Months")
# plt.ylabel("Total units sold per month")
# plt.title("Company sales data for last year")
# plt.grid(True)
# plt.legend()
